# %%
# %autosave 0
import pandas as pd
import numpy as np
import sklearn.preprocessing
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style="white", palette="muted", color_codes=True)
pd.set_option("display.max_rows", 100)
# Out:
# Autosave disabled

# %% [markdown]
# ## Import data

# %%
filename_raw = "data-2017-05-11-0947.csv"
df = pd.read_csv(filename_raw, low_memory=True, header=0)
df.head(n=2)
# Out:
#           id interface source  task      timestamp  \
# 0   other-72      rsvp  image  easy  1492633914824
# 1  other-530      rsvp  image  easy  1492633914926
#
#                                    uuid value
# 0  379307c1-1320-44c5-826a-194c6ae3c763   NaN
# 1  379307c1-1320-44c5-826a-194c6ae3c763   NaN

# %%
len(df["uuid"].unique())
# Out:
# 27

# %% [markdown]
# ## Preprocessing
#
# - reorder columns:
# ```
# timetstamp, uuid, interface, task, source, id, value
# ```
#
# - later, process columns to combine the `id` and `value` columns.
# - filter out observations from when the interface had a data collection issue.
# - filter out users that did not complete all tasks

# %%
def reorder_columns(df):
    cols = ["timestamp", "uuid", "interface", "task", "source", "id", "value"]
    df = df[cols]
    return df
df = reorder_columns(df)

# %%
df.to_csv("01_Reorder_columns.csv", index=True)

# %% [markdown]
# ## Exploration

# %% [markdown]
# Summary of how many images people saw, by user, interface, and task.

# %%
df = pd.read_csv("01_Reorder_columns.csv", index_col=0)
df.head()
# Out:
#        timestamp                                  uuid interface  task source  \
# 0  1492633914824  379307c1-1320-44c5-826a-194c6ae3c763      rsvp  easy  image
# 1  1492633914926  379307c1-1320-44c5-826a-194c6ae3c763      rsvp  easy  image
# 2  1492633915027  379307c1-1320-44c5-826a-194c6ae3c763      rsvp  easy  image
# 3  1492633915129  379307c1-1320-44c5-826a-194c6ae3c763      rsvp  easy  image
# 4  1492633915230  379307c1-1320-44c5-826a-194c6ae3c763      rsvp  easy  image
#
#           id value
# 0   other-72   NaN
# 1  other-530   NaN
# 2  other-575   NaN
# 3  other-594   NaN
# 4  other-582   NaN

# %%
df.ix[df["source"] == "image",:].groupby(["uuid", "interface", "task"]).count()
# Out:
#                                                          timestamp  source  \
# uuid                                 interface   task
# 12b1d3dc-228b-4bf9-b145-639a9c4b6bee rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
#                                      traditional easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
# 36b75c12-970e-43fd-b129-5960c2c10675 rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
# 379307c1-1320-44c5-826a-194c6ae3c763 rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
# 3e040e04-6e89-4765-9079-085c51b0ad18 rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
#                                      traditional easy          240     240
#                                                  hard          240     240
#                                                  medium        128     128
# 4d5c2ff2-1794-4ec2-b8a1-ef7c02543967 rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
#                                      traditional easy          240     240
#                                                  hard          112     112
#                                                  medium        128     128
# 54dcb6dc-be27-497f-a68f-821dfeb6ca96 rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
#                                      traditional easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
# 5fb56330-3c5f-4243-924c-e5457789918b rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
#                                      traditional easy          240     240
#                                                  hard          240     240
#                                                  medium        128     128
# 716faa5b-3528-4ea2-bb9e-e3d8340608f0 rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
#                                      traditional easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
# 797f7757-5ad7-4c98-9ff5-a6e5d6d2eb0d rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
#                                      traditional easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
# 7a803995-3b85-49f2-924b-9d32d2425807 rsvp        easy          240     240
#                                                  hard          240     240
# ...                                                            ...     ...
# b5ac1c45-d258-441f-aeee-b574c2eb8005 traditional medium        240     240
# b7c650c1-c651-413f-912a-72e7491579ed rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
#                                      traditional easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
# b834995d-3bd4-4361-9b36-30ceb0b694a0 rsvp        easy          414     414
#                                                  hard          256     256
#                                                  medium        220     220
#                                      traditional easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
# cca6cbfb-7bd1-4307-bfea-8d8c212cfceb rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
# d1b7965a-4526-477e-b8f8-4c993b4c3244 rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
#                                      traditional hard          240     240
# dd5db699-84ee-48fb-b85b-bada27b55294 rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
#                                      traditional easy          128     128
#                                                  hard          240     240
#                                                  medium        240     240
# df7d905b-7124-40c0-8794-7b4e70325bf6 rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
# e46a57b9-ed7e-4de7-8ba8-86c711debd84 rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
# f7984516-6843-4f99-bc7c-559d1af4de7d rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
#                                      traditional easy          128     128
#                                                  hard          240     240
#                                                  medium        240     240
# fecd21b6-88f4-4abe-b118-fac3a57dd429 rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
#                                      traditional easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
# ffc49fa7-843c-4678-9e94-c2d3f54f2317 rsvp        easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
#                                      traditional easy          240     240
#                                                  hard          240     240
#                                                  medium        240     240
#
#                                                           id  value
# uuid                                 interface   task
# 12b1d3dc-228b-4bf9-b145-639a9c4b6bee rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
#                                      traditional easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
# 36b75c12-970e-43fd-b129-5960c2c10675 rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
# 379307c1-1320-44c5-826a-194c6ae3c763 rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
# 3e040e04-6e89-4765-9079-085c51b0ad18 rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
#                                      traditional easy    240      0
#                                                  hard    240      0
#                                                  medium  128      0
# 4d5c2ff2-1794-4ec2-b8a1-ef7c02543967 rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
#                                      traditional easy    240      0
#                                                  hard    112      0
#                                                  medium  128      0
# 54dcb6dc-be27-497f-a68f-821dfeb6ca96 rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
#                                      traditional easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
# 5fb56330-3c5f-4243-924c-e5457789918b rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
#                                      traditional easy    240      0
#                                                  hard    240      0
#                                                  medium  128      0
# 716faa5b-3528-4ea2-bb9e-e3d8340608f0 rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
#                                      traditional easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
# 797f7757-5ad7-4c98-9ff5-a6e5d6d2eb0d rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
#                                      traditional easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
# 7a803995-3b85-49f2-924b-9d32d2425807 rsvp        easy    240      0
#                                                  hard    240      0
# ...                                                      ...    ...
# b5ac1c45-d258-441f-aeee-b574c2eb8005 traditional medium  240      0
# b7c650c1-c651-413f-912a-72e7491579ed rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
#                                      traditional easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
# b834995d-3bd4-4361-9b36-30ceb0b694a0 rsvp        easy    414      0
#                                                  hard    256      0
#                                                  medium  220      0
#                                      traditional easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
# cca6cbfb-7bd1-4307-bfea-8d8c212cfceb rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
# d1b7965a-4526-477e-b8f8-4c993b4c3244 rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
#                                      traditional hard    240      0
# dd5db699-84ee-48fb-b85b-bada27b55294 rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
#                                      traditional easy    128      0
#                                                  hard    240      0
#                                                  medium  240      0
# df7d905b-7124-40c0-8794-7b4e70325bf6 rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
# e46a57b9-ed7e-4de7-8ba8-86c711debd84 rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
# f7984516-6843-4f99-bc7c-559d1af4de7d rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
#                                      traditional easy    128      0
#                                                  hard    240      0
#                                                  medium  240      0
# fecd21b6-88f4-4abe-b118-fac3a57dd429 rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
#                                      traditional easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
# ffc49fa7-843c-4678-9e94-c2d3f54f2317 rsvp        easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
#                                      traditional easy    240      0
#                                                  hard    240      0
#                                                  medium  240      0
#
# [137 rows x 4 columns]

# %% [markdown]
# Number of users who saw n=240 images for each interface/task combination.

# %%
n=240
df2 = df.ix[df["source"] == "image",:].groupby("uuid").count()
df2[df2["id"] == n * 6]
# Out:
#                                       timestamp  interface  task  source  \
# uuid
# 12b1d3dc-228b-4bf9-b145-639a9c4b6bee       1440       1440  1440    1440
# 54dcb6dc-be27-497f-a68f-821dfeb6ca96       1440       1440  1440    1440
# 716faa5b-3528-4ea2-bb9e-e3d8340608f0       1440       1440  1440    1440
# 797f7757-5ad7-4c98-9ff5-a6e5d6d2eb0d       1440       1440  1440    1440
# 7a803995-3b85-49f2-924b-9d32d2425807       1440       1440  1440    1440
# 7be5a317-6964-4ea6-8d93-f3bb16b10cd6       1440       1440  1440    1440
# b7c650c1-c651-413f-912a-72e7491579ed       1440       1440  1440    1440
# fecd21b6-88f4-4abe-b118-fac3a57dd429       1440       1440  1440    1440
# ffc49fa7-843c-4678-9e94-c2d3f54f2317       1440       1440  1440    1440
#
#                                         id  value
# uuid
# 12b1d3dc-228b-4bf9-b145-639a9c4b6bee  1440      0
# 54dcb6dc-be27-497f-a68f-821dfeb6ca96  1440      0
# 716faa5b-3528-4ea2-bb9e-e3d8340608f0  1440      0
# 797f7757-5ad7-4c98-9ff5-a6e5d6d2eb0d  1440      0
# 7a803995-3b85-49f2-924b-9d32d2425807  1440      0
# 7be5a317-6964-4ea6-8d93-f3bb16b10cd6  1440      0
# b7c650c1-c651-413f-912a-72e7491579ed  1440      0
# fecd21b6-88f4-4abe-b118-fac3a57dd429  1440      0
# ffc49fa7-843c-4678-9e94-c2d3f54f2317  1440      0

# %%
df2[df2["id"] < n * 6]
# Out:
#                                       timestamp  interface  task  source  \
# uuid
# 36b75c12-970e-43fd-b129-5960c2c10675        720        720   720     720
# 379307c1-1320-44c5-826a-194c6ae3c763        720        720   720     720
# 3e040e04-6e89-4765-9079-085c51b0ad18       1328       1328  1328    1328
# 4d5c2ff2-1794-4ec2-b8a1-ef7c02543967       1200       1200  1200    1200
# 5fb56330-3c5f-4243-924c-e5457789918b       1328       1328  1328    1328
# 83910ff3-b87a-45b1-b45f-0ce3a2464dc5       1328       1328  1328    1328
# 95e9f4d4-97e6-4cea-a80c-b62ed866e79b       1434       1434  1434    1434
# 967b4b18-ca20-48de-a642-9c6a26f28284        720        720   720     720
# ab2a8422-0c53-4d49-9a60-cdf810b4a89e        240        240   240     240
# b5ac1c45-d258-441f-aeee-b574c2eb8005       1328       1328  1328    1328
# cca6cbfb-7bd1-4307-bfea-8d8c212cfceb        720        720   720     720
# d1b7965a-4526-477e-b8f8-4c993b4c3244        960        960   960     960
# dd5db699-84ee-48fb-b85b-bada27b55294       1328       1328  1328    1328
# df7d905b-7124-40c0-8794-7b4e70325bf6        720        720   720     720
# e46a57b9-ed7e-4de7-8ba8-86c711debd84        720        720   720     720
# f7984516-6843-4f99-bc7c-559d1af4de7d       1328       1328  1328    1328
#
#                                         id  value
# uuid
# 36b75c12-970e-43fd-b129-5960c2c10675   720      0
# 379307c1-1320-44c5-826a-194c6ae3c763   720      0
# 3e040e04-6e89-4765-9079-085c51b0ad18  1328      0
# 4d5c2ff2-1794-4ec2-b8a1-ef7c02543967  1200      0
# 5fb56330-3c5f-4243-924c-e5457789918b  1328      0
# 83910ff3-b87a-45b1-b45f-0ce3a2464dc5  1328      0
# 95e9f4d4-97e6-4cea-a80c-b62ed866e79b  1434      0
# 967b4b18-ca20-48de-a642-9c6a26f28284   720      0
# ab2a8422-0c53-4d49-9a60-cdf810b4a89e   240      0
# b5ac1c45-d258-441f-aeee-b574c2eb8005  1328      0
# cca6cbfb-7bd1-4307-bfea-8d8c212cfceb   720      0
# d1b7965a-4526-477e-b8f8-4c993b4c3244   960      0
# dd5db699-84ee-48fb-b85b-bada27b55294  1328      0
# df7d905b-7124-40c0-8794-7b4e70325bf6   720      0
# e46a57b9-ed7e-4de7-8ba8-86c711debd84   720      0
# f7984516-6843-4f99-bc7c-559d1af4de7d  1328      0

# %%
# Check if there is a same user with refreshed browser?
ids = ["36b75c12-970e-43fd-b129-5960c2c10675", "cca6cbfb-7bd1-4307-bfea-8d8c212cfceb"]
df.ix[(df["source"] == "image") & (df["uuid"].isin(ids)), :].groupby(["uuid", "interface", "task"]).count()
# Out:
#                                                        timestamp  source   id  \
# uuid                                 interface task
# 36b75c12-970e-43fd-b129-5960c2c10675 rsvp      easy          240     240  240
#                                                hard          240     240  240
#                                                medium        240     240  240
# cca6cbfb-7bd1-4307-bfea-8d8c212cfceb rsvp      easy          240     240  240
#                                                hard          240     240  240
#                                                medium        240     240  240
#
#                                                        value
# uuid                                 interface task
# 36b75c12-970e-43fd-b129-5960c2c10675 rsvp      easy        0
#                                                hard        0
#                                                medium      0
# cca6cbfb-7bd1-4307-bfea-8d8c212cfceb rsvp      easy        0
#                                                hard        0
#                                                medium      0

# %%
# nope, unfortunately they are both RSVP users.

# %% [markdown]
# ## Tranform to combine id and value columns

# %%
df = pd.read_csv("01_Reorder_columns.csv", index_col=0)
def combine_id_value(df2):
    df2["tmp"] = df2["value"]
    df2.ix[~df2["id"].isnull(), "tmp"] = df2.ix[~df2["id"].isnull(), "id"]
    del df2["id"]
    del df2["value"]
    df2.rename(columns={"tmp":"value"}, inplace=True)
    return df2

df = combine_id_value(df)

# %%
df.tail()
# Out:
#            timestamp                                  uuid interface  task  \
# 46284  1494357927038  b834995d-3bd4-4361-9b36-30ceb0b694a0      rsvp  hard
# 46285  1494357927038  b834995d-3bd4-4361-9b36-30ceb0b694a0      rsvp  hard
# 46286  1494357927141  b834995d-3bd4-4361-9b36-30ceb0b694a0      rsvp  hard
# 46287  1494357927141  b834995d-3bd4-4361-9b36-30ceb0b694a0      rsvp  hard
# 46288  1494357927141  b834995d-3bd4-4361-9b36-30ceb0b694a0      rsvp  hard
#
#       source      value
# 46284  image  other-484
# 46285  image  other-481
# 46286  image  other-284
# 46287  image  other-415
# 46288  image    hard-30

# %%
df.to_csv("02_Combine_id_value.csv", index=True)

# %% [markdown]
# ## Convert timestamps into datetimes.

# %%
df = pd.read_csv("02_Combine_id_value.csv", index_col=0)

# %%
df.head()
# Out:
#        timestamp                                  uuid interface  task source  \
# 0  1492633914824  379307c1-1320-44c5-826a-194c6ae3c763      rsvp  easy  image
# 1  1492633914926  379307c1-1320-44c5-826a-194c6ae3c763      rsvp  easy  image
# 2  1492633915027  379307c1-1320-44c5-826a-194c6ae3c763      rsvp  easy  image
# 3  1492633915129  379307c1-1320-44c5-826a-194c6ae3c763      rsvp  easy  image
# 4  1492633915230  379307c1-1320-44c5-826a-194c6ae3c763      rsvp  easy  image
#
#        value
# 0   other-72
# 1  other-530
# 2  other-575
# 3  other-594
# 4  other-582

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"]*1000000)

# %%
df.head()
# Out:
#                 timestamp                                  uuid interface  \
# 0 2017-04-19 20:31:54.824  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
# 1 2017-04-19 20:31:54.926  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
# 2 2017-04-19 20:31:55.027  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
# 3 2017-04-19 20:31:55.129  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
# 4 2017-04-19 20:31:55.230  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
#
#    task source      value
# 0  easy  image   other-72
# 1  easy  image  other-530
# 2  easy  image  other-575
# 3  easy  image  other-594
# 4  easy  image  other-582

# %%
df.dtypes
# Out:
# timestamp    datetime64[ns]
# uuid                 object
# interface            object
# task                 object
# source               object
# value                object
# dtype: object

# %%
# time difference since start of task in milleseconds
grouped = df.groupby(["uuid", "interface", "task"])
grouped = grouped["timestamp"]
time_difference = grouped.transform(lambda x: x - x.iloc[0])

# %%
df["timedelta"] = time_difference.apply(lambda t: t.timestamp())

# %%
df.head(n=1)
# Out:
#                 timestamp                                  uuid interface  \
# 0 2017-04-19 20:31:54.824  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
#
#    task source     value  timedelta
# 0  easy  image  other-72        0.0

# %%
df = df.reset_index(drop=True)

# %%
df.to_csv("03_cleaned.csv")

# %% [markdown]
# # another step
#
# - set uuid, interface, task as compound index? maybe not
# - first plot. show distribution of time to identify images for traditional interface, easy task.

# %%
df = pd.read_csv("03_cleaned.csv", index_col=0)

# %%
df.head()
# Out:
#                  timestamp                                  uuid interface  \
# 0  2017-04-19 20:31:54.824  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
# 1  2017-04-19 20:31:54.926  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
# 2  2017-04-19 20:31:55.027  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
# 3  2017-04-19 20:31:55.129  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
# 4  2017-04-19 20:31:55.230  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
#
#    task source      value  timedelta
# 0  easy  image   other-72      0.000
# 1  easy  image  other-530      0.102
# 2  easy  image  other-575      0.203
# 3  easy  image  other-594      0.305
# 4  easy  image  other-582      0.406

# %% [markdown]
# Here, let's extract data for the traditional interface and put things in a nice manner.
#
# We want schema
# uuid, task, task_index, timestamp, id, label, pred, delay

# %%
df = df.ix[df["interface"] == "traditional", ["uuid", "task", "source", "value", "timedelta"]]
df.head(n=1)
# Out:
#                                       uuid    task source     value  timedelta
# 2880  83910ff3-b87a-45b1-b45f-0ce3a2464dc5  medium  image  medium-9        0.0

# %%
def f(df):
    # extract id and label from source/value
    tmp = df.ix[df["source"] == "image", "value"]
    tmp = tmp.reset_index(drop=True)
    id_ = tmp.apply(lambda g: g.split('-')[1])
    label = tmp.apply(lambda g: g.split('-')[0])
    
    # extract prediction from key/value
    prediction = df.ix[df["source"] == "key", "value"]
    prediction = prediction.reset_index(drop=True)
    
    # compute time differences by aligning source and key subsets
    time_key = df.ix[df["source"] == "key", "timedelta"].reset_index(drop=True)
    time_image = df.ix[df["source"] == "image", "timedelta"].reset_index(drop=True)
    delay = time_key - time_image
    
    # post-process to turn keypresses and tasks into 0/1
    unique_labels = label.unique()
    neg_label = "other"
    pos_label = list(filter(lambda x: x != neg_label, unique_labels))[0] # this is super elaborate :(
    def key_map(key):
        d = {"f": 0, "j": 1}
        return d[key]
    def label_map(task):
        d = {neg_label:0, pos_label:1}
        return d[task]
    label = label.apply(label_map)
    prediction = prediction.apply(key_map)
    
    return pd.DataFrame({"id" : id_, "label" : label, "prediction" : prediction, "delay" : delay})

# %%
df = df.groupby(["uuid", "task"]).apply(f)

# %%
df.index.rename("task_index", level=2, inplace=True)

# %%
df.head(n=3)
# Out:
#                                                       delay   id  label  \
# uuid                                 task task_index
# 12b1d3dc-228b-4bf9-b145-639a9c4b6bee easy 0           3.982  574      0
#                                           1           0.470  159      0
#                                           2           0.509  182      0
#
#                                                       prediction
# uuid                                 task task_index
# 12b1d3dc-228b-4bf9-b145-639a9c4b6bee easy 0                  0.0
#                                           1                  0.0
#                                           2                  0.0

# %%
df.to_csv("04_grouped_and_tranformed.csv")

# %% [markdown]
# ## Pre-processing the RSVP data

# %%
df = pd.read_csv("03_cleaned.csv", index_col=0)
df.head()
# Out:
#                  timestamp                                  uuid interface  \
# 0  2017-04-19 20:31:54.824  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
# 1  2017-04-19 20:31:54.926  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
# 2  2017-04-19 20:31:55.027  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
# 3  2017-04-19 20:31:55.129  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
# 4  2017-04-19 20:31:55.230  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
#
#    task source      value  timedelta
# 0  easy  image   other-72      0.000
# 1  easy  image  other-530      0.102
# 2  easy  image  other-575      0.203
# 3  easy  image  other-594      0.305
# 4  easy  image  other-582      0.406

# %%
# filter out rsvp events and delete interface column
cols = list(df.columns)
cols.remove("interface")
df = df.ix[df["interface"] == "rsvp", cols]

# %%
# find each uuid, task tuple that has at least 1 image shown. then, count the number 
# of keypresses for that uuid, task. remove all image and keypress events if the count
# is equal to or below `threshold`.
def get_good_rsvp(df, threshold):
    df1 = df.copy()
    grouped = df.ix[df["source"] == "image", :].groupby(["uuid", "task"])
    
    for name, group in grouped:
        nkeys = len(df.ix[(df["uuid"] == name[0]) 
                          & (df["task"] == name[1]) 
                          & (df["source"] == "key"), :])
        print(name)
        print("Found key events: {}".format(nkeys))
        if nkeys <= threshold:
            print("Less than threshold. Deleting.")
            # delete all rows matching this uuid and task
            mask = ~((df1["uuid"] == name[0]) & (df1["task"] == name[1]))
            df1 = df1.ix[mask, :]
            
    df1 = df1.reset_index(drop=True)
    
    return df1

# %%
df.head(n=3)
# Out:
#                  timestamp                                  uuid  task source  \
# 0  2017-04-19 20:31:54.824  379307c1-1320-44c5-826a-194c6ae3c763  easy  image
# 1  2017-04-19 20:31:54.926  379307c1-1320-44c5-826a-194c6ae3c763  easy  image
# 2  2017-04-19 20:31:55.027  379307c1-1320-44c5-826a-194c6ae3c763  easy  image
#
#        value  timedelta
# 0   other-72      0.000
# 1  other-530      0.102
# 2  other-575      0.203

# %%
df = get_good_rsvp(df, 0)
# Out:
# ('12b1d3dc-228b-4bf9-b145-639a9c4b6bee', 'easy')
# Found key events: 18
# ('12b1d3dc-228b-4bf9-b145-639a9c4b6bee', 'hard')
# Found key events: 13
# ('12b1d3dc-228b-4bf9-b145-639a9c4b6bee', 'medium')
# Found key events: 16
# ('36b75c12-970e-43fd-b129-5960c2c10675', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('36b75c12-970e-43fd-b129-5960c2c10675', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('36b75c12-970e-43fd-b129-5960c2c10675', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('379307c1-1320-44c5-826a-194c6ae3c763', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('379307c1-1320-44c5-826a-194c6ae3c763', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('379307c1-1320-44c5-826a-194c6ae3c763', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('3e040e04-6e89-4765-9079-085c51b0ad18', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('3e040e04-6e89-4765-9079-085c51b0ad18', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('3e040e04-6e89-4765-9079-085c51b0ad18', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('4d5c2ff2-1794-4ec2-b8a1-ef7c02543967', 'easy')
# Found key events: 8
# ('4d5c2ff2-1794-4ec2-b8a1-ef7c02543967', 'hard')
# Found key events: 7
# ('4d5c2ff2-1794-4ec2-b8a1-ef7c02543967', 'medium')
# Found key events: 11
# ('54dcb6dc-be27-497f-a68f-821dfeb6ca96', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('54dcb6dc-be27-497f-a68f-821dfeb6ca96', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('54dcb6dc-be27-497f-a68f-821dfeb6ca96', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('5fb56330-3c5f-4243-924c-e5457789918b', 'easy')
# Found key events: 14
# ('5fb56330-3c5f-4243-924c-e5457789918b', 'hard')
# Found key events: 7
# ('5fb56330-3c5f-4243-924c-e5457789918b', 'medium')
# Found key events: 10
# ('716faa5b-3528-4ea2-bb9e-e3d8340608f0', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('716faa5b-3528-4ea2-bb9e-e3d8340608f0', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('716faa5b-3528-4ea2-bb9e-e3d8340608f0', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('797f7757-5ad7-4c98-9ff5-a6e5d6d2eb0d', 'easy')
# Found key events: 17
# ('797f7757-5ad7-4c98-9ff5-a6e5d6d2eb0d', 'hard')
# Found key events: 12
# ('797f7757-5ad7-4c98-9ff5-a6e5d6d2eb0d', 'medium')
# Found key events: 16
# ('7a803995-3b85-49f2-924b-9d32d2425807', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('7a803995-3b85-49f2-924b-9d32d2425807', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('7a803995-3b85-49f2-924b-9d32d2425807', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('7be5a317-6964-4ea6-8d93-f3bb16b10cd6', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('7be5a317-6964-4ea6-8d93-f3bb16b10cd6', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('7be5a317-6964-4ea6-8d93-f3bb16b10cd6', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('83910ff3-b87a-45b1-b45f-0ce3a2464dc5', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('83910ff3-b87a-45b1-b45f-0ce3a2464dc5', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('83910ff3-b87a-45b1-b45f-0ce3a2464dc5', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('95e9f4d4-97e6-4cea-a80c-b62ed866e79b', 'easy')
# Found key events: 22
# ('95e9f4d4-97e6-4cea-a80c-b62ed866e79b', 'hard')
# Found key events: 16
# ('95e9f4d4-97e6-4cea-a80c-b62ed866e79b', 'medium')
# Found key events: 23
# ('967b4b18-ca20-48de-a642-9c6a26f28284', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('967b4b18-ca20-48de-a642-9c6a26f28284', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('967b4b18-ca20-48de-a642-9c6a26f28284', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('aacc44cd-8f82-458b-a65b-b94b43df5ab9', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('aacc44cd-8f82-458b-a65b-b94b43df5ab9', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('aacc44cd-8f82-458b-a65b-b94b43df5ab9', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('b5ac1c45-d258-441f-aeee-b574c2eb8005', 'easy')
# Found key events: 24
# ('b5ac1c45-d258-441f-aeee-b574c2eb8005', 'hard')
# Found key events: 18
# ('b5ac1c45-d258-441f-aeee-b574c2eb8005', 'medium')
# Found key events: 24
# ('b7c650c1-c651-413f-912a-72e7491579ed', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('b7c650c1-c651-413f-912a-72e7491579ed', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('b7c650c1-c651-413f-912a-72e7491579ed', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('b834995d-3bd4-4361-9b36-30ceb0b694a0', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('b834995d-3bd4-4361-9b36-30ceb0b694a0', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('b834995d-3bd4-4361-9b36-30ceb0b694a0', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('cca6cbfb-7bd1-4307-bfea-8d8c212cfceb', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('cca6cbfb-7bd1-4307-bfea-8d8c212cfceb', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('cca6cbfb-7bd1-4307-bfea-8d8c212cfceb', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('d1b7965a-4526-477e-b8f8-4c993b4c3244', 'easy')
# Found key events: 15
# ('d1b7965a-4526-477e-b8f8-4c993b4c3244', 'hard')
# Found key events: 7
# ('d1b7965a-4526-477e-b8f8-4c993b4c3244', 'medium')
# Found key events: 8
# ('dd5db699-84ee-48fb-b85b-bada27b55294', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('dd5db699-84ee-48fb-b85b-bada27b55294', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('dd5db699-84ee-48fb-b85b-bada27b55294', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('df7d905b-7124-40c0-8794-7b4e70325bf6', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('df7d905b-7124-40c0-8794-7b4e70325bf6', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('df7d905b-7124-40c0-8794-7b4e70325bf6', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('e46a57b9-ed7e-4de7-8ba8-86c711debd84', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('e46a57b9-ed7e-4de7-8ba8-86c711debd84', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('e46a57b9-ed7e-4de7-8ba8-86c711debd84', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('f7984516-6843-4f99-bc7c-559d1af4de7d', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('f7984516-6843-4f99-bc7c-559d1af4de7d', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('f7984516-6843-4f99-bc7c-559d1af4de7d', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('fecd21b6-88f4-4abe-b118-fac3a57dd429', 'easy')
# Found key events: 16
# ('fecd21b6-88f4-4abe-b118-fac3a57dd429', 'hard')
# Found key events: 12
# ('fecd21b6-88f4-4abe-b118-fac3a57dd429', 'medium')
# Found key events: 16
# ('ffc49fa7-843c-4678-9e94-c2d3f54f2317', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('ffc49fa7-843c-4678-9e94-c2d3f54f2317', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('ffc49fa7-843c-4678-9e94-c2d3f54f2317', 'medium')
# Found key events: 11

# %%
len(df)
# Out:
# 6355

# %%
df.head()
# Out:
#                  timestamp                                  uuid  task source  \
# 0  2017-05-02 20:51:15.593  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
# 1  2017-05-02 20:51:15.695  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
# 2  2017-05-02 20:51:15.802  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
# 3  2017-05-02 20:51:15.904  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
# 4  2017-05-02 20:51:16.019  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
#
#        value  timedelta
# 0  other-379      0.000
# 1     easy-8      0.102
# 2   other-26      0.209
# 3  other-183      0.311
# 4  other-530      0.426

# %%
# extract image shows
df_images = df.ix[df["source"] == "image",:].reset_index(drop=True)
df_images["id"] = df_images["value"].apply(lambda x: x.split('-')[1])
df_images["label"] = df_images["value"].apply(lambda x: x.split('-')[0])
del df_images["value"]
df_images.head(n=2)
# Out:
#                  timestamp                                  uuid  task source  \
# 0  2017-05-02 20:51:15.593  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
# 1  2017-05-02 20:51:15.695  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
#
#    timedelta   id  label
# 0      0.000  379  other
# 1      0.102    8   easy

# %%
# label to 0/1
def label_map(label):
    if label=="other":
        return 0
    else:
        return 1
df_images["label"] = df_images["label"].apply(label_map)

# %%
df_images.head(n=2)
# Out:
#                  timestamp                                  uuid  task source  \
# 0  2017-05-02 20:51:15.593  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
# 1  2017-05-02 20:51:15.695  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
#
#    timedelta   id  label
# 0      0.000  379      0
# 1      0.102    8      1

# %%
df_images.to_csv("06_RSVP_images.csv")

# %%
# extract key presses
df_keys = df.ix[df["source"] == "key", :].reset_index(drop=True)

# %%
df_keys = df_keys.ix[:, ["timestamp", "uuid", "task", "source", "timedelta"]]

# %%
df_keys.to_csv("06_RSVP_keys.csv")
