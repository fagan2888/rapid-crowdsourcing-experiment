# %%
# %autosave 0
import pandas as pd
import numpy as np
import sklearn.preprocessing
#import seaborn as sns
#import matplotlib.pyplot as plt
#%matplotlib inline
#sns.set(style="white", palette="muted", color_codes=True)
pd.set_option("display.max_rows", 100)
# Out:
# Autosave disabled

# %% [markdown]
# ## Import data

# %%
filename_raw = "data-2017-05-11-0947.csv"
df = pd.read_csv(filename_raw, low_memory=True, header=0)
df["event_id"] = np.arange(0, len(df))
display(df.head(n=2))
display(df.tail(n=2))
# Out:
#           id interface source  task      timestamp  \
# 0   other-72      rsvp  image  easy  1492633914824
# 1  other-530      rsvp  image  easy  1492633914926
#
#                                    uuid value  event_id
# 0  379307c1-1320-44c5-826a-194c6ae3c763   NaN         0
# 1  379307c1-1320-44c5-826a-194c6ae3c763   NaN         1
#               id interface source  task      timestamp  \
# 46287  other-415      rsvp  image  hard  1494357927141
# 46288    hard-30      rsvp  image  hard  1494357927141
#
#                                        uuid value  event_id
# 46287  b834995d-3bd4-4361-9b36-30ceb0b694a0   NaN     46287
# 46288  b834995d-3bd4-4361-9b36-30ceb0b694a0   NaN     46288

# %%
len(df["uuid"].unique())
# Out:
# 27

# %% [markdown]
# ## Preprocessing
#
# - quickly map uuids into human-readable names
# - reorder columns:
# ```
# timetstamp, uuid, interface, task, source, id, value
# ```
#
# - later, process columns to combine the `id` and `value` columns.
# - filter out observations from when the interface had a data collection issue.
# - filter out users that did not complete all tasks

# %%
names = ["Alice", "Bob", "Charlie", "Dana", "Ellen", "Fred",
         "Gary", "Henry", "Irene", "Joseph", "Kenneth", "Louise",
         "Micah", "Nancy", "Odin", "Patty", "Quentin", "Randall",
         "Samantha", "Tracy", "Umberto", "Yolanda", "Zed",
         "Steve", "Brenda", "Christine", "Rachel", "Jon"]
import numpy as np
uuids = df["uuid"].unique()
uuids_unique, uuids_indices = np.unique(uuids, return_inverse=True)
d = {u: names[uuids_indices[i]] for i, u in enumerate(uuids_unique)}
df["uuid"] = df["uuid"].map(d)

# %%
def reorder_columns(df):
    cols = ["timestamp", "uuid", "interface", "task", "source", "id", "value", "event_id"]
    df = df[cols]
    return df
df = reorder_columns(df)

# %% [markdown]
# ## Exploration

# %% [markdown]
# Summary of how many images people saw, by user, interface, and task.

# %%
(df
 .query("source == 'image'")
 .groupby(["uuid", "interface", "task"])
 .count())
# Out:
#                               timestamp  source   id  value
# uuid      interface   task
# Alice     rsvp        easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
#           traditional easy          128     128  128      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
# Bob       rsvp        easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
# Brenda    rsvp        easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
#           traditional easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
# Charlie   rsvp        easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
#           traditional easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
# Christine rsvp        easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
#           traditional easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
# Dana      rsvp        easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
#           traditional easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
# Ellen     rsvp        easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
#           traditional easy          240     240  240      0
#                       hard          128     128  128      0
#                       medium        240     240  240      0
# Fred      rsvp        easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
# Gary      traditional medium        240     240  240      0
# Henry     rsvp        easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
#           traditional easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
# Irene     rsvp        easy          240     240  240      0
# ...                                 ...     ...  ...    ...
# Patty     rsvp        medium        240     240  240      0
#           traditional easy          128     128  128      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
# Quentin   rsvp        easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
#           traditional easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
# Rachel    rsvp        easy          414     414  414      0
#                       hard          256     256  256      0
#                       medium        220     220  220      0
#           traditional easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
# Randall   rsvp        easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
#           traditional easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
# Samantha  rsvp        easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
#           traditional easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
# Steve     rsvp        easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
# Tracy     rsvp        easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
#           traditional hard          240     240  240      0
# Umberto   rsvp        easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
#           traditional easy          128     128  128      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
# Yolanda   rsvp        easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
#           traditional easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        515     515  515      0
# Zed       rsvp        easy          240     240  240      0
#                       hard          240     240  240      0
#                       medium        240     240  240      0
#
# [137 rows x 4 columns]

# %% [markdown]
# Number of users who saw n=240 images for each interface/task combination.

# %%
n_images = 240
n_interfaces = 2
n_tasks = 3
n = n_images * n_interfaces * n_tasks

# %%
def set_of_users_who_saw_tasks(symbol):
    return (df
            .query("source == 'image'")
            .groupby("uuid")
            .count()
            .query("id {symbol} @n".format(symbol=symbol))
            [["id"]]
            .rename(columns={"id":"count"}))

# %%
# Set of users who saw exactly n=240 for each interface/task
set_of_users_who_saw_tasks('==')
# Out:
#            count
# uuid
# Brenda      1440
# Charlie     1440
# Christine   1440
# Dana        1440
# Henry       1440
# Odin        1440
# Quentin     1440
# Randall     1440
# Samantha    1440

# %%
# Set of users who saw *less than* n=240 for each interface/task
set_of_users_who_saw_tasks('<')
# Out:
#          count
# uuid
# Alice     1328
# Bob        720
# Ellen     1328
# Fred       720
# Gary       240
# Irene      720
# Joseph    1200
# Kenneth   1328
# Louise    1328
# Micah      720
# Nancy     1434
# Patty     1328
# Steve      720
# Tracy      960
# Umberto   1328
# Zed        720

# %%
# Set of users who saw *more than* n=240 for each interface/task
set_of_users_who_saw_tasks('>')
# Out:
#          count
# uuid
# Rachel    1610
# Yolanda   1715

# %%
# We can see that there are two uuids, both with less than n tasks, that add up to n.
# Were they the same user, with a refreshed browser perhaps?
# Verdict: Unfortunately, both uuids are just associated with rsvp.
ids = map(lambda k: d[k], ["36b75c12-970e-43fd-b129-5960c2c10675", "cca6cbfb-7bd1-4307-bfea-8d8c212cfceb"])
(df
 .loc[(df["source"] == "image") & (df["uuid"].isin(ids)), :]
 .groupby(["uuid", "interface", "task"])
 .count()
 [["id"]]
 .rename(columns={"id":"count"}))
# Out:
#                         count
# uuid  interface task
# Micah rsvp      easy      240
#                 hard      240
#                 medium    240
# Steve rsvp      easy      240
#                 hard      240
#                 medium    240

# %% [markdown]
# ## Tranform to combine id and value columns

# %%
df = df.copy()
inds = df["id"].notnull()
df.loc[inds, "value"] = df.loc[inds, "id"]
del df["id"]

# %% [markdown]
# ## Convert timestamps into datetimes.

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"]*1000000)

# %%
df.tail(n=3)
# Out:
#                     timestamp    uuid interface  task source      value
# 46286 2017-05-09 19:25:27.141  Rachel      rsvp  hard  image  other-284
# 46287 2017-05-09 19:25:27.141  Rachel      rsvp  hard  image  other-415
# 46288 2017-05-09 19:25:27.141  Rachel      rsvp  hard  image    hard-30

# %%
# time difference since start of task in milleseconds
df["timedelta"] = (df
                   .groupby(["uuid", "interface", "task"])
                   ["timestamp"]
                   .transform(lambda x: x - x.iloc[0])
                   .apply(lambda t: t.to_pytimedelta().total_seconds())
                  )

# %% [markdown]
# ### Some brief exploration, while the data is still "raw"

# %%
n=999
with pd.option_context("display.max_rows", n):
    display(df.sort_values(by="timestamp").query("uuid == 'Charlie' & interface == 'rsvp'"))
# Out:
#                     timestamp     uuid interface    task source      value  \
easy    240.0   NaN
#           hard    240.0   NaN
#           medium  240.0   NaN
# Bob       easy    240.0   NaN
#           hard    240.0   NaN
#           medium  240.0   NaN
# Brenda    easy    240.0   NaN
#           hard    240.0   NaN
#           medium  240.0   NaN
# Charlie   easy    240.0  18.0
#           hard    240.0  13.0
#           medium  240.0  16.0
# Christine easy    240.0   NaN
#           hard    240.0   NaN
#           medium  240.0   NaN
# Dana      easy    240.0  17.0
#           hard    240.0  12.0
#           medium  240.0  16.0
# Ellen     easy    240.0  24.0
#           hard    240.0  18.0
#           medium  240.0  24.0
# Fred      easy    240.0   NaN
#           hard    240.0   NaN
#           medium  240.0   NaN
# Henry     easy    240.0   NaN
#           hard    240.0   NaN
#           medium  240.0   NaN
# Irene     easy    240.0   NaN
#           hard    240.0   NaN
#           medium  240.0   NaN
# Joseph    easy    240.0   8.0
#           hard    240.0   7.0
#           medium  240.0  11.0
# Kenneth   easy    240.0  14.0
#           hard    240.0   7.0
#           medium  240.0  10.0
# Louise    easy    240.0   NaN
#           hard    240.0   NaN
#           medium  240.0   NaN
# Micah     easy    240.0   NaN
#           hard    240.0   NaN
#           medium  240.0   NaN
# Nancy     easy    234.0  22.0
#           hard    240.0  16.0
#           medium  240.0  23.0
# Odin      easy    240.0   NaN
#           hard    240.0   NaN
#           medium  240.0   NaN
# Patty     easy    240.0   NaN
#           hard    240.0   NaN
#           medium  240.0   NaN
# Quentin   easy    240.0  16.0
#           hard    240.0  12.0
#           medium  240.0  16.0
# Rachel    easy    414.0   NaN
#           hard    256.0   NaN
#           medium  220.0   NaN
# Randall   easy    240.0   NaN
#           hard    240.0   NaN
#           medium  240.0   NaN
# Samantha  easy    240.0   NaN
#           hard    240.0   NaN
#           medium  240.0  11.0
# Steve     easy    240.0   NaN
#           hard    240.0   NaN
#           medium  240.0   NaN
# Tracy     easy    240.0  15.0
#           hard    240.0   7.0
#           medium  240.0   8.0
# Umberto   easy    240.0   NaN
#           hard    240.0   NaN
#           medium  240.0   NaN
# Yolanda   easy    240.0   NaN
#           hard    240.0   NaN
#           medium  240.0   NaN
# Zed       easy    240.0   NaN
#           hard    240.0   NaN
#           medium  240.0   NaN

# %%
(df
 .query('interface == "rsvp"')
 .groupby(["uuid", "task"]).apply(lambda _df: _df["source"].value_counts())
 .unstack())

# %% [markdown]
# ## Change schema

# %% [markdown]
# Here, let's extract data for the traditional interface and put things in a nice manner.
#
# We want schema
# ```
# uuid, task, task_index, id, true_label, pred_label, delay
# ```

# %%
df = (df
      .query("interface == 'traditional'")
      .drop(["interface", "timestamp"], axis=1))

# %%
df.head(n=1)
# Out:
#        uuid    task source     value  timedelta
# 2880  Patty  medium  image  medium-9        0.0

# %%
def process_task(df):
    image_mask = df["source"] == "image"
    key_mask   = df["source"] == "key"

    # image id as given by image name
    id_ser = (df
              .loc[image_mask, "value"]
              .apply(lambda x: x.split("-")[1]))

    # true label as given by image name
    true_label_ser = (df
                      .loc[image_mask, "value"]
                      .apply(lambda x: x.split("-")[0])
                      .map(lambda x: 0 if x=="other" else 1))

    # predicted label as identified from key press events
    pred_label_ser = (df
                      .loc[key_mask, "value"]
                      .map({"f": 0, "j": 1}))

    # align timedelta from key events and from show events and subtract
    # TODO double check this part; consider joining on "value", then subtracting with axis=1
    delay_ser = (df.loc[key_mask, "timedelta"].reset_index(drop=True) -
                 df.loc[image_mask, "timedelta"].reset_index(drop=True))

    return pd.DataFrame({"id": id_ser,
                         "true_label": true_label_ser,
                         "pred_label": pred_label_ser,
                         "delay": delay_ser})

# %%
df = (df
      .groupby(["uuid", "task"])
      .apply(process_task))
df.head(n=2)
# Out:
#               delay   id  pred_label  true_label
# uuid  task
# Alice easy 0  0.377  NaN         NaN         NaN
#            1  0.367  NaN         NaN         NaN

# %%
df.index = df.index.rename("task_index", level=2)

# %%
df.head(n=3)

# %% [markdown]
# ## Pre-processing the RSVP data

# %%
df = pd.read_csv("03_cleaned.csv", index_col=0)
df.head()
# Out:
#                  timestamp                                  uuid interface  \
# 0  2017-04-19 20:31:54.824  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
# 1  2017-04-19 20:31:54.926  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
# 2  2017-04-19 20:31:55.027  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
# 3  2017-04-19 20:31:55.129  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
# 4  2017-04-19 20:31:55.230  379307c1-1320-44c5-826a-194c6ae3c763      rsvp
#
#    task source      value  timedelta
# 0  easy  image   other-72      0.000
# 1  easy  image  other-530      0.102
# 2  easy  image  other-575      0.203
# 3  easy  image  other-594      0.305
# 4  easy  image  other-582      0.406

# %%
# filter out rsvp events and delete interface column
cols = list(df.columns)
cols.remove("interface")
df = df.ix[df["interface"] == "rsvp", cols]

# %%
# find each uuid, task tuple that has at least 1 image shown. then, count the number 
# of keypresses for that uuid, task. remove all image and keypress events if the count
# is equal to or below `threshold`.
def get_good_rsvp(df, threshold):
    df1 = df.copy()
    grouped = df.ix[df["source"] == "image", :].groupby(["uuid", "task"])
    
    for name, group in grouped:
        nkeys = len(df.ix[(df["uuid"] == name[0]) 
                          & (df["task"] == name[1]) 
                          & (df["source"] == "key"), :])
        print(name)
        print("Found key events: {}".format(nkeys))
        if nkeys <= threshold:
            print("Less than threshold. Deleting.")
            # delete all rows matching this uuid and task
            mask = ~((df1["uuid"] == name[0]) & (df1["task"] == name[1]))
            df1 = df1.ix[mask, :]
            
    df1 = df1.reset_index(drop=True)
    
    return df1

# %%
df.head(n=3)
# Out:
#                  timestamp                                  uuid  task source  \
# 0  2017-04-19 20:31:54.824  379307c1-1320-44c5-826a-194c6ae3c763  easy  image
# 1  2017-04-19 20:31:54.926  379307c1-1320-44c5-826a-194c6ae3c763  easy  image
# 2  2017-04-19 20:31:55.027  379307c1-1320-44c5-826a-194c6ae3c763  easy  image
#
#        value  timedelta
# 0   other-72      0.000
# 1  other-530      0.102
# 2  other-575      0.203

# %%
df = get_good_rsvp(df, 0)
# Out:
# ('12b1d3dc-228b-4bf9-b145-639a9c4b6bee', 'easy')
# Found key events: 18
# ('12b1d3dc-228b-4bf9-b145-639a9c4b6bee', 'hard')
# Found key events: 13
# ('12b1d3dc-228b-4bf9-b145-639a9c4b6bee', 'medium')
# Found key events: 16
# ('36b75c12-970e-43fd-b129-5960c2c10675', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('36b75c12-970e-43fd-b129-5960c2c10675', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('36b75c12-970e-43fd-b129-5960c2c10675', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('379307c1-1320-44c5-826a-194c6ae3c763', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('379307c1-1320-44c5-826a-194c6ae3c763', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('379307c1-1320-44c5-826a-194c6ae3c763', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('3e040e04-6e89-4765-9079-085c51b0ad18', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('3e040e04-6e89-4765-9079-085c51b0ad18', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('3e040e04-6e89-4765-9079-085c51b0ad18', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('4d5c2ff2-1794-4ec2-b8a1-ef7c02543967', 'easy')
# Found key events: 8
# ('4d5c2ff2-1794-4ec2-b8a1-ef7c02543967', 'hard')
# Found key events: 7
# ('4d5c2ff2-1794-4ec2-b8a1-ef7c02543967', 'medium')
# Found key events: 11
# ('54dcb6dc-be27-497f-a68f-821dfeb6ca96', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('54dcb6dc-be27-497f-a68f-821dfeb6ca96', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('54dcb6dc-be27-497f-a68f-821dfeb6ca96', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('5fb56330-3c5f-4243-924c-e5457789918b', 'easy')
# Found key events: 14
# ('5fb56330-3c5f-4243-924c-e5457789918b', 'hard')
# Found key events: 7
# ('5fb56330-3c5f-4243-924c-e5457789918b', 'medium')
# Found key events: 10
# ('716faa5b-3528-4ea2-bb9e-e3d8340608f0', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('716faa5b-3528-4ea2-bb9e-e3d8340608f0', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('716faa5b-3528-4ea2-bb9e-e3d8340608f0', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('797f7757-5ad7-4c98-9ff5-a6e5d6d2eb0d', 'easy')
# Found key events: 17
# ('797f7757-5ad7-4c98-9ff5-a6e5d6d2eb0d', 'hard')
# Found key events: 12
# ('797f7757-5ad7-4c98-9ff5-a6e5d6d2eb0d', 'medium')
# Found key events: 16
# ('7a803995-3b85-49f2-924b-9d32d2425807', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('7a803995-3b85-49f2-924b-9d32d2425807', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('7a803995-3b85-49f2-924b-9d32d2425807', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('7be5a317-6964-4ea6-8d93-f3bb16b10cd6', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('7be5a317-6964-4ea6-8d93-f3bb16b10cd6', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('7be5a317-6964-4ea6-8d93-f3bb16b10cd6', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('83910ff3-b87a-45b1-b45f-0ce3a2464dc5', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('83910ff3-b87a-45b1-b45f-0ce3a2464dc5', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('83910ff3-b87a-45b1-b45f-0ce3a2464dc5', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('95e9f4d4-97e6-4cea-a80c-b62ed866e79b', 'easy')
# Found key events: 22
# ('95e9f4d4-97e6-4cea-a80c-b62ed866e79b', 'hard')
# Found key events: 16
# ('95e9f4d4-97e6-4cea-a80c-b62ed866e79b', 'medium')
# Found key events: 23
# ('967b4b18-ca20-48de-a642-9c6a26f28284', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('967b4b18-ca20-48de-a642-9c6a26f28284', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('967b4b18-ca20-48de-a642-9c6a26f28284', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('aacc44cd-8f82-458b-a65b-b94b43df5ab9', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('aacc44cd-8f82-458b-a65b-b94b43df5ab9', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('aacc44cd-8f82-458b-a65b-b94b43df5ab9', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('b5ac1c45-d258-441f-aeee-b574c2eb8005', 'easy')
# Found key events: 24
# ('b5ac1c45-d258-441f-aeee-b574c2eb8005', 'hard')
# Found key events: 18
# ('b5ac1c45-d258-441f-aeee-b574c2eb8005', 'medium')
# Found key events: 24
# ('b7c650c1-c651-413f-912a-72e7491579ed', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('b7c650c1-c651-413f-912a-72e7491579ed', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('b7c650c1-c651-413f-912a-72e7491579ed', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('b834995d-3bd4-4361-9b36-30ceb0b694a0', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('b834995d-3bd4-4361-9b36-30ceb0b694a0', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('b834995d-3bd4-4361-9b36-30ceb0b694a0', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('cca6cbfb-7bd1-4307-bfea-8d8c212cfceb', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('cca6cbfb-7bd1-4307-bfea-8d8c212cfceb', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('cca6cbfb-7bd1-4307-bfea-8d8c212cfceb', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('d1b7965a-4526-477e-b8f8-4c993b4c3244', 'easy')
# Found key events: 15
# ('d1b7965a-4526-477e-b8f8-4c993b4c3244', 'hard')
# Found key events: 7
# ('d1b7965a-4526-477e-b8f8-4c993b4c3244', 'medium')
# Found key events: 8
# ('dd5db699-84ee-48fb-b85b-bada27b55294', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('dd5db699-84ee-48fb-b85b-bada27b55294', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('dd5db699-84ee-48fb-b85b-bada27b55294', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('df7d905b-7124-40c0-8794-7b4e70325bf6', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('df7d905b-7124-40c0-8794-7b4e70325bf6', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('df7d905b-7124-40c0-8794-7b4e70325bf6', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('e46a57b9-ed7e-4de7-8ba8-86c711debd84', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('e46a57b9-ed7e-4de7-8ba8-86c711debd84', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('e46a57b9-ed7e-4de7-8ba8-86c711debd84', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('f7984516-6843-4f99-bc7c-559d1af4de7d', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('f7984516-6843-4f99-bc7c-559d1af4de7d', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('f7984516-6843-4f99-bc7c-559d1af4de7d', 'medium')
# Found key events: 0
# Less than threshold. Deleting.
# ('fecd21b6-88f4-4abe-b118-fac3a57dd429', 'easy')
# Found key events: 16
# ('fecd21b6-88f4-4abe-b118-fac3a57dd429', 'hard')
# Found key events: 12
# ('fecd21b6-88f4-4abe-b118-fac3a57dd429', 'medium')
# Found key events: 16
# ('ffc49fa7-843c-4678-9e94-c2d3f54f2317', 'easy')
# Found key events: 0
# Less than threshold. Deleting.
# ('ffc49fa7-843c-4678-9e94-c2d3f54f2317', 'hard')
# Found key events: 0
# Less than threshold. Deleting.
# ('ffc49fa7-843c-4678-9e94-c2d3f54f2317', 'medium')
# Found key events: 11

# %%
len(df)
# Out:
# 6355

# %%
df.head()
# Out:
#                  timestamp                                  uuid  task source  \
# 0  2017-05-02 20:51:15.593  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
# 1  2017-05-02 20:51:15.695  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
# 2  2017-05-02 20:51:15.802  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
# 3  2017-05-02 20:51:15.904  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
# 4  2017-05-02 20:51:16.019  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
#
#        value  timedelta
# 0  other-379      0.000
# 1     easy-8      0.102
# 2   other-26      0.209
# 3  other-183      0.311
# 4  other-530      0.426

# %%
# extract image shows
df_images = df.ix[df["source"] == "image",:].reset_index(drop=True)
df_images["id"] = df_images["value"].apply(lambda x: x.split('-')[1])
df_images["label"] = df_images["value"].apply(lambda x: x.split('-')[0])
del df_images["value"]
df_images.head(n=2)
# Out:
#                  timestamp                                  uuid  task source  \
# 0  2017-05-02 20:51:15.593  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
# 1  2017-05-02 20:51:15.695  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
#
#    timedelta   id  label
# 0      0.000  379  other
# 1      0.102    8   easy

# %%
# label to 0/1
def label_map(label):
    if label=="other":
        return 0
    else:
        return 1
df_images["label"] = df_images["label"].apply(label_map)

# %%
df_images.head(n=2)
# Out:
#                  timestamp                                  uuid  task source  \
# 0  2017-05-02 20:51:15.593  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
# 1  2017-05-02 20:51:15.695  5fb56330-3c5f-4243-924c-e5457789918b  easy  image
#
#    timedelta   id  label
# 0      0.000  379      0
# 1      0.102    8      1

# %%
df_images.to_csv("06_RSVP_images.csv")

# %%
# extract key presses
df_keys = df.ix[df["source"] == "key", :].reset_index(drop=True)

# %%
df_keys = df_keys.ix[:, ["timestamp", "uuid", "task", "source", "timedelta"]]

# %%
df_keys.to_csv("06_RSVP_keys.csv")
